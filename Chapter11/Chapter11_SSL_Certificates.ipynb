# %% [markdown]
# # Chapter 11: SSL Configuration with Let's Encrypt
#
# ## Introduction
# Secure your n8n endpoint with automated SSL/TLS certificates.
#
# ## Objective
# Secure your n8n endpoint with free, automated SSL/TLS certificates provided by Let's Encrypt.
#
# ## Tools & Technologies
# - Certbot
# - Let's Encrypt
#
# ## Conclusion
# Your instance is now fully encrypted with a valid certificate.
