# %% [markdown]
# # Chapter 27: High Availability Setup (Horizontal Scaling)
#
# ## Introduction
# Configure n8n for zero-downtime and high throughput using multiple instances behind a load balancer.
