# %% [markdown]
# # Chapter 23: Fly.io: Global n8n Deployment and Latency Management
#
# ## Introduction
# Run n8n at the edge.
#
# ## Objective
# Run n8n globally on the fly.io edge network to reduce latency for your automation tasks.
#
# ## Tools & Technologies
# - Fly.io
#
# ## Conclusion
# n8n is now deployed close to your users/webhooks globally.
