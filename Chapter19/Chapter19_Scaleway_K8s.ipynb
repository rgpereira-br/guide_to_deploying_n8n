# %% [markdown]
# # Chapter 19: Scaleway: Using Kapsule for Managed Kubernetes n8n
#
# ## Introduction
# Enter managed Kubernetes on Scaleway.
#
# ## Objective
# Deploy n8n on a managed Kubernetes cluster on Scaleway for advanced container orchestration.
#
# ## Tools & Technologies
# - Scaleway Kapsule
# - Kubernetes
#
# ## Conclusion
# n8n is cluster-ready.
