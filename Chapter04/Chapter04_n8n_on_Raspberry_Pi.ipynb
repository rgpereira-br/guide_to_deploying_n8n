# %% [markdown]
# # Chapter 04: n8n on Raspberry Pi
#
# ## Introduction
# A Raspberry Pi is an excellent low-power option for a 24/7 automation hub.
#
# ## Objective
# Set up a dedicated, low-power n8n automation server on a Raspberry Pi using optimized ARM configurations.
#
# ## Tools & Technologies
# - Raspberry Pi OS
# - Docker
# - Portainer
#
# ## Conclusion
# Your n8n instance is now running on a dedicated local hardware.
