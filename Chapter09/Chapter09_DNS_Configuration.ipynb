# %% [markdown]
# # Chapter 09: Pointing Domains and Subdomains: DNS
#
# ## Introduction
# Map your professional identity to your n8n server.
#
# ## Objective
# Configure DNS records at your registrar to map custom domains or subdomains to your n8n deployment's IP address.
#
# ## Tools & Technologies
# - Cloudflare DNS
# - Namecheap
# - A/CNAME Records
#
# ## Conclusion
# n8n is now reachable via your custom domain.
