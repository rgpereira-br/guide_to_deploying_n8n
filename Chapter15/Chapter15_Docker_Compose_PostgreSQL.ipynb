# %% [markdown]
# # Chapter 15: Docker Compose with External PostgreSQL
#
# ## Introduction
# By default, n8n uses SQLite. For production, switching to an external PostgreSQL database is highly recommended.
