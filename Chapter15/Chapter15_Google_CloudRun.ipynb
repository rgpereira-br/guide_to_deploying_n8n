# %% [markdown]
# # Chapter 15: Google Cloud Run: Serverless n8n
#
# ## Introduction
# Run n8n without servers with pay-as-you-go pricing.
#
# ## Objective
# Run n8n as a serverless container on Google Cloud to benefit from automatic scaling and pay-as-you-go pricing.
#
# ## Tools & Technologies
# - Google Cloud Run
# - Cloud SQL
#
# ## Conclusion
# n8n is now scalable and serverless on GCP.
