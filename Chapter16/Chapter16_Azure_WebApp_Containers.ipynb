# %% [markdown]
# # Chapter 16: Microsoft Azure: Deploying n8n with Web App for Containers
#
# ## Introduction
# Managed containers in the Microsoft ecosystem.
#
# ## Objective
# Host n8n on Azure using the Web App for Containers service for easy scaling within the Microsoft ecosystem.
#
# ## Tools & Technologies
# - Azure Web App for Containers
#
# ## Conclusion
# n8n is cloud-ready on Azure.
