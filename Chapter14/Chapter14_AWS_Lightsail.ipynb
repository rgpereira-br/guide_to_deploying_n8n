# %% [markdown]
# # Chapter 14: AWS Lightsail and Docker Deployment
#
# ## Introduction
# Simplified AWS hosting for n8n.
#
# ## Objective
# Set up n8n on Amazon Web Services using Lightsail for predictable pricing and simplified server management.
#
# ## Tools & Technologies
# - AWS Lightsail
# - Docker
#
# ## Conclusion
# You have a professional AWS setup with a fixed monthly cost.
